# %% [markdown]
# This script is dedicated to explore the departments (de: Ressort) with relation to the author mapping.

# %%
import json
import sqlite3
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import scipy
import networkx as nx
from dateutil import relativedelta
from datetime import datetime
import re
import tqdm
from src.models.MatchingType import MatchingType

# %%
con = sqlite3.connect('../data/interim/articles_with_author_mapping.db')
cur = con.cursor()

# %%
# get top 30 authors
rows = cur.execute('select name from unmapped_authors where matching_type = ? group by name order by count(*) desc limit 50', (MatchingType.IS_FULL_NAME,)).fetchall()
authors = [row[0] for row in rows]

# %%
# remove  None from authors
authors = [author for author in authors if author is not None]

# %%
authors
# Out:
# ['Ekkehard Schulreich',
#  'André Neumann',
#  'Julia Tonne',
#  'Nikos Natsidis',
#  'Olaf Barth',
#  'Christian Kunze',
#  'Thomas Sparrer',
#  'Christine Jacob',
#  'Jörg ter Vehn',
#  'Heike Liesaus',
#  'Dirk Wurzel',
#  'Simone Prenzel',
#  'Frank Prenzel',
#  'Jens Rometsch',
#  'Matthias Puppe',
#  'Steffi Robak',
#  'Thomas Haegeler',
#  'Axel Kaminski',
#  'Ulrike Witt',
#  'Jens Rosenkranz',
#  'Matthias Roth',
#  'Steffen Brost',
#  'Mathias Orbeck',
#  'Kerstin Decker',
#  'Ilka Fischer',
#  'Frank Pfeifer',
#  'Kathrin Kabelitz',
#  'Jana Brechlin',
#  'Frank Hörügel',
#  'Andreas Tappert',
#  'Frank Schmidt',
#  'Kay Würker',
#  'Frank Döring',
#  'Nico Fliegner',
#  'Haig Latchinian',
#  'Olaf Krenz',
#  'Roland Heinrich',
#  'Kai-Uwe Brandt',
#  'Olaf Büchel',
#  'Roger Dietze',
#  'Robert Nößler',
#  'Hagen Rösner',
#  'Evelyn ter Vehn',
#  'Bastian Fischer',
#  'Jörg Wolf',
#  'Janina Fleischer',
#  'Mathias Schönknecht',
#  'Jörg Reuter',
#  'Gislinde Redepenning',
#  'Manuel Niemann']

# %%
json_authors = [json.dumps(author) for author in authors]

# %%
'(' + ','.join(json_authors) + ')'
# Out:
# '("Ekkehard Schulreich","Andr\\u00e9 Neumann","Julia Tonne","Nikos Natsidis","Olaf Barth","Christian Kunze","Thomas Sparrer","Christine Jacob","J\\u00f6rg ter Vehn","Heike Liesaus","Dirk Wurzel","Simone Prenzel","Frank Prenzel","Jens Rometsch","Matthias Puppe","Steffi Robak","Thomas Haegeler","Axel Kaminski","Ulrike Witt","Jens Rosenkranz","Matthias Roth","Steffen Brost","Mathias Orbeck","Kerstin Decker","Ilka Fischer","Frank Pfeifer","Kathrin Kabelitz","Jana Brechlin","Frank H\\u00f6r\\u00fcgel","Andreas Tappert","Frank Schmidt","Kay W\\u00fcrker","Frank D\\u00f6ring","Nico Fliegner","Haig Latchinian","Olaf Krenz","Roland Heinrich","Kai-Uwe Brandt","Olaf B\\u00fcchel","Roger Dietze","Robert N\\u00f6\\u00dfler","Hagen R\\u00f6sner","Evelyn ter Vehn","Bastian Fischer","J\\u00f6rg Wolf","Janina Fleischer","Mathias Sch\\u00f6nknecht","J\\u00f6rg Reuter","Gislinde Redepenning","Manuel Niemann")'

# %%
rows = cur.execute("SELECT ar.id, ar.article_namespace_array, ar.published_at, a.name FROM articles ar join article_authors aa on ar.id = aa.article_id join unmapped_authors a on aa.author_id = a.id where a.name in " + '(' + ','.join(json_authors) + ')').fetchall()

# %%
departments = pd.DataFrame(columns=['id', 'department', 'published_at', 'name'], data=rows)

# %%
departments
# Out:
#            id                       department               published_at  \
# 0        1517            ["Region", "Oschatz"]  2021-12-10T08:17:00+00:00
# 1        1522             ["Region", "Taucha"]  2021-12-10T08:31:00+00:00
# 2        1526            ["Region", "Doebeln"]  2021-12-10T09:00:28+00:00
# 3        1531  ["Region", "Mitteldeutschland"]  2021-12-10T09:57:24+00:00
# 4        1532             ["Region", "Grimma"]  2021-12-10T09:53:00+00:00
# ...       ...                              ...                        ...
# 74606  367671           ["Leipzig", "Lokales"]  2010-01-02T06:47:41+00:00
# 74607  367684             ["Region", "Grimma"]  2010-01-01T04:00:00+00:00
# 74608  367690         ["Region", "Bad-Dueben"]  2010-01-01T12:41:42+00:00
# 74609  367698         ["Region", "Bad-Dueben"]  2010-01-01T15:00:00+00:00
# 74610  367709           ["Leipzig", "Lokales"]  2010-01-01T22:35:30+00:00
#
#                   name
# 0      Christian Kunze
# 1           Olaf Barth
# 2       Thomas Sparrer
# 3       Manuel Niemann
# 4        Frank Prenzel
# ...                ...
# 74606   Kai-Uwe Brandt
# 74607    Frank Schmidt
# 74608    Nico Fliegner
# 74609    Nico Fliegner
# 74610    Jens Rometsch
#
# [74611 rows x 4 columns]

# %%
departments["department"] = departments["department"].apply(lambda x: json.loads(x))

# %%
departments = departments.explode('department')

# %%
# remove rows where department equals "Region" or "Nachrichten" for being to unspecific
departments = departments[departments.department != 'Region']
departments = departments[departments.department != 'Nachrichten']
departments
# Out:
#            id         department               published_at             name
# 0        1517            Oschatz  2021-12-10T08:17:00+00:00  Christian Kunze
# 1        1522             Taucha  2021-12-10T08:31:00+00:00       Olaf Barth
# 2        1526            Doebeln  2021-12-10T09:00:28+00:00   Thomas Sparrer
# 3        1531  Mitteldeutschland  2021-12-10T09:57:24+00:00   Manuel Niemann
# 4        1532             Grimma  2021-12-10T09:53:00+00:00    Frank Prenzel
# ...       ...                ...                        ...              ...
# 74607  367684             Grimma  2010-01-01T04:00:00+00:00    Frank Schmidt
# 74608  367690         Bad-Dueben  2010-01-01T12:41:42+00:00    Nico Fliegner
# 74609  367698         Bad-Dueben  2010-01-01T15:00:00+00:00    Nico Fliegner
# 74610  367709            Leipzig  2010-01-01T22:35:30+00:00    Jens Rometsch
# 74610  367709            Lokales  2010-01-01T22:35:30+00:00    Jens Rometsch
#
# [96735 rows x 4 columns]

# %%
# create pandas data frame with author name and their department in that they wrote the most articles
author_departments = departments.groupby(['name', 'department']).agg('count').sort_values(by='id', ascending=False).reset_index()
# for each author get row with highest count
author_departments = author_departments.groupby('name').head(1)
# drop column id
author_departments = author_departments.drop(columns=['id'])
# rename column published_at to article_count
author_departments = author_departments.rename(columns={'published_at': 'article_count'})

# %%
author_departments
# Out:
#                     name    department  article_count
# 0    Ekkehard Schulreich      Geithain           3403
# 1        Christine Jacob     Delitzsch           2396
# 2         Nikos Natsidis         Borna           2269
# 3         Thomas Sparrer       Doebeln           2187
# 4        Christian Kunze       Oschatz           2174
# 5            Dirk Wurzel       Doebeln           2144
# 6            Julia Tonne         Borna           2079
# 7         Matthias Puppe       Leipzig           1808
# 8        Jens Rosenkranz       Leipzig           1711
# 9           Steffi Robak       Doebeln           1709
# 10       Evelyn ter Vehn       Leipzig           1688
# 11       Thomas Haegeler     Altenburg           1665
# 12         Jens Rometsch       Leipzig           1632
# 14         Axel Kaminski       Oschatz           1573
# 16        Mathias Orbeck       Leipzig           1499
# 17           Ulrike Witt  Markkleeberg           1496
# 18            Olaf Krenz         Borna           1484
# 19        Kerstin Decker       Leipzig           1404
# 20         Frank Prenzel        Grimma           1377
# 21         Jana Brechlin       Oschatz           1356
# 22       Andreas Tappert       Leipzig           1340
# 23         Steffen Brost    Bad-Dueben           1331
# 24       Roland Heinrich    Schkeuditz           1330
# 25         Frank Pfeifer        Grimma           1311
# 26            Olaf Barth        Taucha           1297
# 28         Heike Liesaus     Delitzsch           1188
# 30        Kai-Uwe Brandt        Wurzen           1170
# 31        Simone Prenzel        Wurzen           1080
# 34       Bastian Fischer     Altenburg           1036
# 36         Matthias Roth       Leipzig           1033
# 38      Janina Fleischer        Kultur            992
# 39          Ilka Fischer     Eilenburg            959
# 44      Kathrin Kabelitz    Bad-Dueben            794
# 45         Frank Schmidt        Grimma            782
# 47         Nico Fliegner     Eilenburg            777
# 48  Gislinde Redepenning  Markkleeberg            753
# 49       Haig Latchinian        Grimma            752
# 57          Roger Dietze        Grimma            634
# 62        Manuel Niemann       Oschatz            549

# %%
# for every department chose a random color and append it as a color column to the dataframe
colors = sns.color_palette("hls", len(author_departments.department.unique()))
author_departments['color'] = author_departments.department.apply(lambda x: colors[list(author_departments.department.unique()).index(x)])
author_departments
# Out:
#                     name    department  article_count  \
# 0    Ekkehard Schulreich      Geithain           3403
# 1        Christine Jacob     Delitzsch           2396
# 2         Nikos Natsidis         Borna           2269
# 3         Thomas Sparrer       Doebeln           2187
# 4        Christian Kunze       Oschatz           2174
# 5            Dirk Wurzel       Doebeln           2144
# 6            Julia Tonne         Borna           2079
# 7         Matthias Puppe       Leipzig           1808
# 8        Jens Rosenkranz       Leipzig           1711
# 9           Steffi Robak       Doebeln           1709
# 10       Evelyn ter Vehn       Leipzig           1688
# 11       Thomas Haegeler     Altenburg           1665
# 12         Jens Rometsch       Leipzig           1632
# 14         Axel Kaminski       Oschatz           1573
# 16        Mathias Orbeck       Leipzig           1499
# 17           Ulrike Witt  Markkleeberg           1496
# 18            Olaf Krenz         Borna           1484
# 19        Kerstin Decker       Leipzig           1404
# 20         Frank Prenzel        Grimma           1377
# 21         Jana Brechlin       Oschatz           1356
# 22       Andreas Tappert       Leipzig           1340
# 23         Steffen Brost    Bad-Dueben           1331
# 24       Roland Heinrich    Schkeuditz           1330
# 25         Frank Pfeifer        Grimma           1311
# 26            Olaf Barth        Taucha           1297
# 28         Heike Liesaus     Delitzsch           1188
# 30        Kai-Uwe Brandt        Wurzen           1170
# 31        Simone Prenzel        Wurzen           1080
# 34       Bastian Fischer     Altenburg           1036
# 36         Matthias Roth       Leipzig           1033
# 38      Janina Fleischer        Kultur            992
# 39          Ilka Fischer     Eilenburg            959
# 44      Kathrin Kabelitz    Bad-Dueben            794
# 45         Frank Schmidt        Grimma            782
# 47         Nico Fliegner     Eilenburg            777
# 48  Gislinde Redepenning  Markkleeberg            753
# 49       Haig Latchinian        Grimma            752
# 57          Roger Dietze        Grimma            634
# 62        Manuel Niemann       Oschatz            549
#
#                                               color
# 0               (0.86, 0.3712, 0.33999999999999997)
# 1   (0.86, 0.5791999999999999, 0.33999999999999997)
# 2               (0.86, 0.7872, 0.33999999999999997)
# 3   (0.7247999999999999, 0.86, 0.33999999999999997)
# 4   (0.5167999999999999, 0.86, 0.33999999999999997)
# 5   (0.7247999999999999, 0.86, 0.33999999999999997)
# 6               (0.86, 0.7872, 0.33999999999999997)
# 7               (0.33999999999999997, 0.86, 0.3712)
# 8               (0.33999999999999997, 0.86, 0.3712)
# 9   (0.7247999999999999, 0.86, 0.33999999999999997)
# 10              (0.33999999999999997, 0.86, 0.3712)
# 11  (0.33999999999999997, 0.86, 0.5792000000000002)
# 12              (0.33999999999999997, 0.86, 0.3712)
# 14  (0.5167999999999999, 0.86, 0.33999999999999997)
# 16              (0.33999999999999997, 0.86, 0.3712)
# 17  (0.33999999999999997, 0.86, 0.7872000000000001)
# 18              (0.86, 0.7872, 0.33999999999999997)
# 19              (0.33999999999999997, 0.86, 0.3712)
# 20  (0.33999999999999997, 0.7247999999999999, 0.86)
# 21  (0.5167999999999999, 0.86, 0.33999999999999997)
# 22              (0.33999999999999997, 0.86, 0.3712)
# 23  (0.33999999999999997, 0.5167999999999999, 0.86)
# 24              (0.3712, 0.33999999999999997, 0.86)
# 25  (0.33999999999999997, 0.7247999999999999, 0.86)
# 26  (0.5791999999999999, 0.33999999999999997, 0.86)
# 28  (0.86, 0.5791999999999999, 0.33999999999999997)
# 30  (0.7871999999999999, 0.33999999999999997, 0.86)
# 31  (0.7871999999999999, 0.33999999999999997, 0.86)
# 34  (0.33999999999999997, 0.86, 0.5792000000000002)
# 36              (0.33999999999999997, 0.86, 0.3712)
# 38  (0.86, 0.33999999999999997, 0.7247999999999996)
# 39  (0.86, 0.33999999999999997, 0.5167999999999995)
# 44  (0.33999999999999997, 0.5167999999999999, 0.86)
# 45  (0.33999999999999997, 0.7247999999999999, 0.86)
# 47  (0.86, 0.33999999999999997, 0.5167999999999995)
# 48  (0.33999999999999997, 0.86, 0.7872000000000001)
# 49  (0.33999999999999997, 0.7247999999999999, 0.86)
# 57  (0.33999999999999997, 0.7247999999999999, 0.86)
# 62  (0.5167999999999999, 0.86, 0.33999999999999997)

# %%
# get articles with authors that are in the top 30
rows = cur.execute("SELECT ar.id, a.name FROM articles ar join article_authors aa on ar.id = aa.article_id join unmapped_authors a on aa.author_id = a.id where a.name in " + '(' + ','.join(json_authors) + ')').fetchall()
authors_with_articles = pd.DataFrame(columns=['id', 'name'], data=rows)

# remove the rows where the id does not occur in the whole dataframe more than once
authors_with_articles = authors_with_articles[authors_with_articles.id.isin(authors_with_articles.id.value_counts()[authors_with_articles.id.value_counts() > 1].index)]
authors_with_articles
# Out:
#            id              name
# 70       1786   Thomas Haegeler
# 71       1786   Jens Rosenkranz
# 120      1960      Ilka Fischer
# 121      1960  Kathrin Kabelitz
# 166      2127   Jens Rosenkranz
# ...       ...               ...
# 74531  367317  Kathrin Kabelitz
# 74566  367465     Heike Liesaus
# 74567  367465     Nico Fliegner
# 74572  367516  Kathrin Kabelitz
# 74573  367516     Heike Liesaus
#
# [2320 rows x 2 columns]

# %%
edges = authors_with_articles.groupby('id')['name'].apply(list).tolist()
edges
# Out:
# [['Thomas Haegeler', 'Jens Rosenkranz'],
#  ['Ilka Fischer', 'Kathrin Kabelitz'],
#  ['Jens Rosenkranz', 'Thomas Haegeler'],
#  ['Kathrin Kabelitz', 'Steffen Brost'],
#  ['Axel Kaminski', 'Jana Brechlin', 'Christian Kunze'],
#  ['Jens Rosenkranz', 'Thomas Haegeler'],
#  ['Thomas Haegeler', 'Jens Rosenkranz'],
#  ['Matthias Roth', 'Jens Rometsch'],
#  ['Thomas Haegeler', 'Jens Rosenkranz'],
#  ['Thomas Haegeler', 'Jens Rosenkranz'],
#  ['Thomas Haegeler', 'Jens Rosenkranz'],
#  ['Jens Rosenkranz', 'Thomas Haegeler'],
#  ['Christian Kunze', 'Jana Brechlin', 'Axel Kaminski'],
#  ['Jens Rosenkranz', 'Thomas Haegeler'],
#  ['Jens Rosenkranz', 'Thomas Haegeler'],
#  ['Nikos Natsidis', 'Olaf Krenz'],
#  ['Nikos Natsidis', 'Julia Tonne', 'Ekkehard Schulreich'],
#  ['Frank Prenzel', 'Kai-Uwe Brandt', 'Roger Dietze', 'Frank Pfeifer'],
#  ['Kathrin Kabelitz', 'Axel Kaminski'],
#  ['Andreas Tappert', 'Mathias Orbeck'],
#  ['Nikos Natsidis', 'Ekkehard Schulreich', 'Olaf Krenz'],
#  ['Julia Tonne', 'Nikos Natsidis', 'Ekkehard Schulreich'],
#  ['Dirk Wurzel', 'Thomas Sparrer'],
#  ['Ekkehard Schulreich', 'Olaf Krenz'],
#  ['Kathrin Kabelitz', 'Manuel Niemann'],
#  ['Christian Kunze', 'Axel Kaminski', 'Jana Brechlin'],
#  ['Christine Jacob', 'Kathrin Kabelitz'],
#  ['Thomas Sparrer', 'Steffi Robak', 'Dirk Wurzel'],
#  ['Jens Rosenkranz', 'Thomas Haegeler'],
#  ['Matthias Roth', 'Andreas Tappert'],
#  ['Kathrin Kabelitz', 'Christine Jacob'],
#  ['Steffi Robak', 'Thomas Sparrer', 'Dirk Wurzel'],
#  ['Julia Tonne', 'Nikos Natsidis'],
#  ['Ekkehard Schulreich', 'Frank Prenzel', 'Kai-Uwe Brandt'],
#  ['Thomas Sparrer', 'Dirk Wurzel'],
#  ['Thomas Sparrer', 'Dirk Wurzel'],
#  ['Mathias Orbeck', 'Nikos Natsidis'],
#  ['Julia Tonne', 'Olaf Krenz'],
#  ['Steffen Brost', 'Ilka Fischer', 'Christine Jacob'],
#  ['Dirk Wurzel', 'Steffi Robak'],
#  ['Ekkehard Schulreich', 'Nikos Natsidis', 'Olaf Krenz'],
#  ['Axel Kaminski', 'Christian Kunze'],
#  ['Ekkehard Schulreich', 'Olaf Krenz'],
#  ['Ekkehard Schulreich', 'Frank Prenzel'],
#  ['Nico Fliegner', 'Christian Kunze', 'Axel Kaminski'],
#  ['Olaf Krenz', 'Julia Tonne'],
#  ['Kathrin Kabelitz', 'Steffen Brost'],
#  ['Jens Rosenkranz', 'Thomas Haegeler'],
#  ['Thomas Sparrer', 'Dirk Wurzel', 'Steffi Robak'],
#  ['Olaf Krenz', 'Frank Prenzel', 'Frank Pfeifer'],
#  ['Matthias Puppe', 'Andreas Tappert'],
#  ['Manuel Niemann', 'Axel Kaminski'],
#  ['Julia Tonne', 'Simone Prenzel'],
#  ['Frank Prenzel', 'Julia Tonne', 'Simone Prenzel'],
#  ['Simone Prenzel', 'Roger Dietze'],
#  ['Jens Rosenkranz', 'Thomas Haegeler'],
#  ['Steffen Brost', 'Jens Rometsch'],
#  ['Ekkehard Schulreich', 'Olaf Krenz'],
#  ['Jens Rosenkranz', 'Thomas Haegeler'],
#  ['Thomas Sparrer', 'Dirk Wurzel'],
#  ['Thomas Sparrer', 'Dirk Wurzel'],
#  ['Simone Prenzel', 'Ekkehard Schulreich'],
#  ['Frank Prenzel', 'Kai-Uwe Brandt', 'Haig Latchinian'],
#  ['Simone Prenzel', 'Kai-Uwe Brandt', 'Roger Dietze'],
#  ['Jens Rosenkranz', 'Bastian Fischer'],
#  ['Kathrin Kabelitz', 'Nico Fliegner'],
#  ['Kathrin Kabelitz', 'Steffen Brost'],
#  ['Nikos Natsidis', 'Simone Prenzel', 'Ekkehard Schulreich'],
#  ['Thomas Haegeler', 'Jens Rosenkranz'],
#  ['Nikos Natsidis', 'Ekkehard Schulreich'],
#  ['Simone Prenzel', 'Nikos Natsidis'],
#  ['Ekkehard Schulreich', 'Julia Tonne', 'Nikos Natsidis'],
#  ['Haig Latchinian', 'Frank Prenzel'],
#  ['Thomas Haegeler', 'Jens Rosenkranz'],
#  ['Kathrin Kabelitz', 'Steffen Brost'],
#  ['Steffen Brost', 'Nico Fliegner', 'Axel Kaminski'],
#  ['Kerstin Decker', 'Mathias Orbeck'],
#  ['Frank Prenzel', 'Haig Latchinian'],
#  ['Frank Prenzel', 'Haig Latchinian'],
#  ['Thomas Sparrer', 'Dirk Wurzel', 'Steffi Robak'],
#  ['Nico Fliegner', 'Kathrin Kabelitz'],
#  ['Thomas Sparrer', 'Steffi Robak'],
#  ['Ekkehard Schulreich', 'Julia Tonne'],
#  ['Frank Prenzel', 'Kai-Uwe Brandt', 'Roger Dietze'],
#  ['Thomas Haegeler', 'Jens Rosenkranz'],
#  ['Haig Latchinian', 'Frank Prenzel'],
#  ['Nico Fliegner', 'Steffen Brost'],
#  ['Frank Pfeifer', 'Julia Tonne', 'Haig Latchinian'],
#  ['Frank Pfeifer', 'Olaf Krenz'],
#  ['Frank Prenzel', 'Frank Pfeifer', 'Haig Latchinian'],
#  ['Nico Fliegner', 'Kathrin Kabelitz', 'Christine Jacob'],
#  ['Thomas Sparrer', 'Dirk Wurzel'],
#  ['Kathrin Kabelitz', 'Steffen Brost'],
#  ['Olaf Krenz', 'Simone Prenzel'],
#  ['Jens Rosenkranz', 'Thomas Haegeler'],
#  ['Thomas Sparrer', 'Dirk Wurzel'],
#  ['Julia Tonne', 'Olaf Krenz'],
#  ['Thomas Sparrer', 'Dirk Wurzel'],
#  ['Jens Rometsch', 'Matthias Roth'],
#  ['Nico Fliegner', 'Steffen Brost', 'Christine Jacob'],
#  ['Thomas Haegeler', 'Bastian Fischer'],
#  ['Thomas Sparrer', 'Dirk Wurzel'],
#  ['Steffi Robak', 'Thomas Sparrer', 'Dirk Wurzel'],
#  ['Jens Rosenkranz', 'Thomas Haegeler'],
#  ['Jana Brechlin', 'Axel Kaminski'],
#  ['Thomas Haegeler', 'Jens Rosenkranz'],
#  ['Andreas Tappert', 'Jens Rosenkranz'],
#  ['Nikos Natsidis', 'Olaf Krenz'],
#  ['Dirk Wurzel', 'Thomas Sparrer'],
#  ['Matthias Roth', 'Andreas Tappert'],
#  ['Ilka Fischer', 'Nico Fliegner'],
#  ['Manuel Niemann', 'Christian Kunze'],
#  ['Kai-Uwe Brandt', 'Roger Dietze'],
#  ['Nikos Natsidis', 'Julia Tonne', 'Ekkehard Schulreich'],
#  ['Manuel Niemann', 'Axel Kaminski'],
#  ['Matthias Puppe', 'Thomas Sparrer'],
#  ['Frank Prenzel', 'Haig Latchinian', 'Frank Pfeifer'],
#  ['Ekkehard Schulreich', 'Julia Tonne', 'Nikos Natsidis'],
#  ['Thomas Sparrer', 'Steffi Robak'],
#  ['Frank Pfeifer',
#   'Haig Latchinian',
#   'Frank Prenzel',
#   'Roger Dietze',
#   'Julia Tonne'],
#  ['Nico Fliegner', 'Steffen Brost', 'Ilka Fischer'],
#  ['Matthias Roth', 'Matthias Puppe'],
#  ['Heike Liesaus', 'Kathrin Kabelitz'],
#  ['Jana Brechlin', 'Axel Kaminski', 'Manuel Niemann'],
#  ['Bastian Fischer', 'Thomas Haegeler'],
#  ['Heike Liesaus', 'Christine Jacob'],
#  ['Julia Tonne', 'Olaf Krenz'],
#  ['Matthias Puppe', 'Steffi Robak'],
#  ['Ekkehard Schulreich', 'Olaf Krenz'],
#  ['Julia Tonne', 'Nikos Natsidis', 'Ekkehard Schulreich'],
#  ['Roger Dietze',
#   'Frank Pfeifer',
#   'Haig Latchinian',
#   'Frank Prenzel',
#   'Kai-Uwe Brandt'],
#  ['Christine Jacob', 'Nico Fliegner'],
#  ['Manuel Niemann', 'Christian Kunze'],
#  ['Ekkehard Schulreich', 'Kai-Uwe Brandt'],
#  ['Thomas Sparrer', 'Bastian Fischer'],
#  ['Kathrin Kabelitz', 'Thomas Sparrer'],
#  ['Steffi Robak', 'Dirk Wurzel', 'Thomas Sparrer'],
#  ['Steffen Brost', 'Kathrin Kabelitz'],
#  ['Thomas Sparrer', 'Steffi Robak'],
#  ['Julia Tonne', 'Roger Dietze'],
#  ['Matthias Puppe', 'Matthias Roth'],
#  ['Nikos Natsidis', 'Simone Prenzel', 'Julia Tonne', 'Kai-Uwe Brandt'],
#  ['Jana Brechlin', 'Christian Kunze'],
#  ['Jana Brechlin', 'Christian Kunze'],
#  ['Christine Jacob', 'Heike Liesaus'],
#  ['Olaf Barth', 'Jens Rometsch', 'Gislinde Redepenning'],
#  ['Nico Fliegner', 'Nico Fliegner'],
#  ['Simone Prenzel', 'Frank Prenzel'],
#  ['Matthias Roth', 'Thomas Haegeler'],
#  ['Dirk Wurzel', 'Thomas Sparrer'],
#  ['Nikos Natsidis', 'Simone Prenzel'],
#  ['Axel Kaminski', 'Jana Brechlin', 'Manuel Niemann'],
#  ['Roger Dietze', 'Julia Tonne'],
#  ['Jens Rosenkranz', 'Bastian Fischer'],
#  ['Nikos Natsidis', 'Julia Tonne', 'Ekkehard Schulreich', 'Olaf Krenz'],
#  ['Roger Dietze', 'Frank Pfeifer', 'Kai-Uwe Brandt'],
#  ['Jana Brechlin', 'Christian Kunze', 'Axel Kaminski', 'Manuel Niemann'],
#  ['Jens Rosenkranz', 'Thomas Haegeler'],
#  ['Frank Pfeifer', 'Frank Prenzel', 'Kai-Uwe Brandt'],
#  ['Julia Tonne', 'Nikos Natsidis', 'Ekkehard Schulreich', 'Olaf Krenz'],
#  ['Manuel Niemann', 'Axel Kaminski'],
#  ['Jens Rosenkranz', 'Thomas Haegeler'],
#  ['Nico Fliegner', 'Kai-Uwe Brandt'],
#  ['Steffen Brost', 'Kai-Uwe Brandt'],
#  ['Nikos Natsidis', 'Frank Pfeifer', 'Kai-Uwe Brandt'],
#  ['Steffen Brost', 'Nico Fliegner'],
#  ['Thomas Sparrer', 'Dirk Wurzel', 'Steffi Robak'],
#  ['Thomas Sparrer', 'Steffi Robak'],
#  ['Thomas Haegeler', 'Jens Rometsch'],
#  ['Roger Dietze', 'Haig Latchinian', 'Frank Pfeifer'],
#  ['Nikos Natsidis', 'Julia Tonne', 'Ekkehard Schulreich'],
#  ['Dirk Wurzel', 'Thomas Sparrer'],
#  ['Roger Dietze', 'Julia Tonne'],
#  ['Haig Latchinian', 'Frank Pfeifer', 'Roger Dietze'],
#  ['Haig Latchinian', 'Steffi Robak'],
#  ['Nico Fliegner', 'Steffen Brost', 'Christine Jacob'],
#  ['Thomas Sparrer', 'Steffi Robak', 'Dirk Wurzel'],
#  ['Ekkehard Schulreich', 'Nikos Natsidis'],
#  ['Steffen Brost', 'Ilka Fischer', 'Nico Fliegner'],
#  ['Jens Rosenkranz', 'Thomas Haegeler'],
#  ['Julia Tonne', 'Roger Dietze'],
#  ['Ekkehard Schulreich', 'Olaf Krenz'],
#  ['Julia Tonne', 'Frank Prenzel', 'Kai-Uwe Brandt'],
#  ['Julia Tonne', 'Ekkehard Schulreich'],
#  ['Steffi Robak', 'Dirk Wurzel'],
#  ['Jana Brechlin', 'Axel Kaminski'],
#  ['Kai-Uwe Brandt', 'Nikos Natsidis', 'Frank Prenzel', 'Olaf Krenz'],
#  ['Thomas Haegeler', 'Jens Rosenkranz'],
#  ['Nikos Natsidis', 'Simone Prenzel'],
#  ['Julia Tonne', 'Ekkehard Schulreich'],
#  ['Bastian Fischer', 'Jens Rosenkranz'],
#  ['Jana Brechlin', 'Manuel Niemann', 'Axel Kaminski'],
#  ['Heike Liesaus', 'Christine Jacob'],
#  ['Steffen Brost', 'Kathrin Kabelitz'],
#  ['Matthias Puppe', 'Matthias Roth'],
#  ['Ilka Fischer', 'Christine Jacob'],
#  ['Christian Kunze', 'Axel Kaminski'],
#  ['Kai-Uwe Brandt', 'Frank Prenzel', 'Simone Prenzel'],
#  ['Ekkehard Schulreich',
#   'Nikos Natsidis',
#   'Simone Prenzel',
#   'Julia Tonne',
#   'Olaf Krenz'],
#  ['Ekkehard Schulreich', 'Simone Prenzel'],
#  ['Christine Jacob', 'Ilka Fischer'],
#  ['Heike Liesaus', 'Axel Kaminski'],
#  ['Roger Dietze', 'Julia Tonne'],
#  ['Julia Tonne', 'Olaf Krenz'],
#  ['Julia Tonne', 'Olaf Krenz'],
#  ['Jana Brechlin', 'Manuel Niemann'],
#  ['Haig Latchinian', 'Jana Brechlin'],
#  ['Jens Rosenkranz', 'Thomas Haegeler'],
#  ['Thomas Sparrer', 'Steffi Robak'],
#  ['Matthias Roth', 'Matthias Puppe'],
#  ['Frank Prenzel', 'Steffi Robak'],
#  ['Mathias Orbeck', 'Jens Rometsch'],
#  ['Olaf Barth', 'Gislinde Redepenning'],
#  ['Ekkehard Schulreich', 'Nikos Natsidis'],
#  ['Heike Liesaus', 'Kathrin Kabelitz'],
#  ['Nikos Natsidis', 'Ekkehard Schulreich', 'Kai-Uwe Brandt', 'Frank Prenzel'],
#  ['Nikos Natsidis', 'Simone Prenzel', 'Ekkehard Schulreich'],
#  ['Dirk Wurzel', 'Steffi Robak'],
#  ['Jana Brechlin', 'Axel Kaminski', 'Manuel Niemann'],
#  ['Thomas Sparrer', 'Dirk Wurzel'],
#  ['Jens Rosenkranz', 'Thomas Haegeler', 'Matthias Roth'],
#  ['Ilka Fischer', 'Heike Liesaus', 'Kathrin Kabelitz'],
#  ['Axel Kaminski', 'Manuel Niemann', 'Christian Kunze'],
#  ['Ekkehard Schulreich', 'Nikos Natsidis', 'Olaf Krenz'],
#  ['Jens Rosenkranz', 'Thomas Haegeler'],
#  ['Thomas Sparrer', 'Steffi Robak', 'Dirk Wurzel'],
#  ['Manuel Niemann', 'Axel Kaminski'],
#  ['Jens Rosenkranz', 'Thomas Haegeler'],
#  ['Jens Rosenkranz', 'Thomas Haegeler'],
#  ['Nikos Natsidis', 'Julia Tonne'],
#  ['Nikos Natsidis', 'Roger Dietze', 'Frank Prenzel', 'Kai-Uwe Brandt'],
#  ['Thomas Sparrer', 'Steffi Robak', 'Dirk Wurzel'],
#  ['Matthias Puppe', 'Matthias Roth'],
#  ['Nikos Natsidis', 'Olaf Krenz'],
#  ['Nico Fliegner', 'Steffen Brost'],
#  ['Thomas Haegeler', 'Matthias Roth'],
#  ['Kathrin Kabelitz', 'Heike Liesaus'],
#  ['Nikos Natsidis', 'Julia Tonne', 'Ekkehard Schulreich', 'Olaf Krenz'],
#  ['Christian Kunze', 'Axel Kaminski'],
#  ['Kathrin Kabelitz', 'Christine Jacob'],
#  ['Manuel Niemann', 'Axel Kaminski'],
#  ['Dirk Wurzel', 'Thomas Sparrer'],
#  ['Matthias Puppe', 'Matthias Roth'],
#  ['Christian Kunze', 'Axel Kaminski'],
#  ['Matthias Puppe', 'Janina Fleischer'],
#  ['Thomas Sparrer', 'Dirk Wurzel'],
#  ['Frank Pfeifer', 'Haig Latchinian'],
#  ['Frank Prenzel', 'Olaf Krenz'],
#  ['Steffen Brost', 'Nico Fliegner'],
#  ['Christian Kunze', 'Axel Kaminski'],
#  ['Nico Fliegner', 'Christine Jacob'],
#  ['Frank Pfeifer', 'Nikos Natsidis'],
#  ['Kathrin Kabelitz', 'Steffen Brost'],
#  ['Kai-Uwe Brandt', 'Nikos Natsidis', 'Haig Latchinian'],
#  ['Nico Fliegner', 'Axel Kaminski'],
#  ['Jana Brechlin', 'Axel Kaminski', 'Manuel Niemann'],
#  ['Manuel Niemann', 'Axel Kaminski'],
#  ['Manuel Niemann', 'Jana Brechlin'],
#  ['Matthias Roth', 'Matthias Puppe'],
#  ['Matthias Puppe', 'Matthias Roth'],
#  ['Matthias Puppe', 'Matthias Roth'],
#  ['Manuel Niemann', 'Axel Kaminski'],
#  ['Heike Liesaus', 'Nico Fliegner', 'Kathrin Kabelitz'],
#  ['Jens Rosenkranz', 'Thomas Haegeler'],
#  ['Bastian Fischer', 'Thomas Haegeler'],
#  ['Ekkehard Schulreich', 'Frank Pfeifer'],
#  ['Thomas Sparrer', 'Ekkehard Schulreich'],
#  ['Julia Tonne', 'Ekkehard Schulreich'],
#  ['Julia Tonne', 'Ekkehard Schulreich'],
#  ['Kathrin Kabelitz', 'Heike Liesaus'],
#  ['Thomas Sparrer', 'Dirk Wurzel'],
#  ['Axel Kaminski', 'Manuel Niemann'],
#  ['Jens Rometsch', 'Matthias Roth'],
#  ['Axel Kaminski', 'Manuel Niemann'],
#  ['Thomas Sparrer', 'Steffi Robak'],
#  ['Christian Kunze', 'Axel Kaminski'],
#  ['Frank Pfeifer', 'Haig Latchinian', 'Roger Dietze', 'Frank Prenzel'],
#  ['Frank Prenzel', 'Haig Latchinian'],
#  ['Axel Kaminski', 'Manuel Niemann'],
#  ['Axel Kaminski', 'Manuel Niemann'],
#  ['Christian Kunze', 'Axel Kaminski'],
#  ['Kathrin Kabelitz', 'Steffen Brost'],
#  ['Christine Jacob', 'Bastian Fischer'],
#  ['Matthias Roth', 'Matthias Puppe'],
#  ['Thomas Haegeler', 'Jens Rosenkranz'],
#  ['Nico Fliegner', 'Steffen Brost'],
#  ['Christine Jacob', 'Heike Liesaus'],
#  ['Nikos Natsidis', 'Simone Prenzel'],
#  ['Nico Fliegner', 'Heike Liesaus', 'Ilka Fischer'],
#  ['Christine Jacob', 'Heike Liesaus'],
#  ['Nico Fliegner', 'Steffen Brost'],
#  ['Axel Kaminski', 'Manuel Niemann'],
#  ['Manuel Niemann', 'Heike Liesaus'],
#  ['Thomas Sparrer', 'Steffi Robak'],
#  ['Axel Kaminski', 'Manuel Niemann'],
#  ['Christian Kunze', 'Jana Brechlin', 'Manuel Niemann'],
#  ['Thomas Sparrer', 'Dirk Wurzel'],
#  ['Nikos Natsidis', 'Christian Kunze'],
#  ['Manuel Niemann', 'Christian Kunze'],
#  ['Axel Kaminski', 'Manuel Niemann'],
#  ['Nikos Natsidis', 'Haig Latchinian'],
#  ['Christian Kunze', 'Manuel Niemann'],
#  ['Julia Tonne', 'Olaf Krenz'],
#  ['Axel Kaminski', 'Manuel Niemann'],
#  ['Axel Kaminski', 'Manuel Niemann'],
#  ['Axel Kaminski', 'Manuel Niemann'],
#  ['Kathrin Kabelitz', 'Heike Liesaus'],
#  ['Jens Rosenkranz', 'Thomas Haegeler'],
#  ['Frank Prenzel', 'Frank Pfeifer'],
#  ['Jens Rosenkranz', 'Thomas Haegeler'],
#  ['Christine Jacob', 'Nico Fliegner'],
#  ['Thomas Haegeler', 'Jens Rosenkranz'],
#  ['Axel Kaminski', 'Manuel Niemann'],
#  ['Thomas Haegeler', 'Jens Rosenkranz'],
#  ['Christian Kunze', 'Manuel Niemann'],
#  ['Jens Rosenkranz', 'Thomas Haegeler'],
#  ['Thomas Haegeler', 'Jens Rosenkranz'],
#  ['Haig Latchinian', 'Matthias Roth'],
#  ['Thomas Haegeler', 'Jens Rosenkranz'],
#  ['Steffi Robak', 'Thomas Sparrer'],
#  ['Nico Fliegner', 'Heike Liesaus'],
#  ['Heike Liesaus', 'Christine Jacob'],
#  ['Thomas Sparrer', 'Dirk Wurzel'],
#  ['Bastian Fischer', 'Jens Rosenkranz'],
#  ['Nico Fliegner', 'Kathrin Kabelitz', 'Christine Jacob'],
#  ['Christian Kunze', 'Manuel Niemann'],
#  ['Nikos Natsidis', 'Olaf Krenz'],
#  ['Jana Brechlin', 'Axel Kaminski', 'Manuel Niemann'],
#  ['Matthias Puppe', 'Jana Brechlin', 'Manuel Niemann'],
#  ['Jana Brechlin', 'Manuel Niemann'],
#  ['Kathrin Kabelitz', 'Ilka Fischer'],
#  ['Steffi Robak', 'Thomas Sparrer'],
#  ['Jens Rosenkranz', 'Thomas Sparrer'],
#  ['Steffi Robak', 'Thomas Sparrer'],
#  ['Axel Kaminski', 'Manuel Niemann'],
#  ['Bastian Fischer', 'Jens Rometsch'],
#  ['Heike Liesaus', 'Nico Fliegner'],
#  ['Jens Rosenkranz', 'Bastian Fischer'],
#  ['Roger Dietze', 'Simone Prenzel'],
#  ['Thomas Haegeler', 'Julia Tonne', 'Frank Prenzel'],
#  ['Jens Rosenkranz', 'Thomas Haegeler'],
#  ['Andreas Tappert', 'Jens Rometsch'],
#  ['Jana Brechlin', 'Axel Kaminski'],
#  ['Manuel Niemann', 'Axel Kaminski', 'Jana Brechlin'],
#  ['Mathias Orbeck', 'Jens Rometsch'],
#  ['Haig Latchinian', 'Frank Pfeifer'],
#  ['Manuel Niemann', 'Axel Kaminski'],
#  ['Jens Rosenkranz', 'Bastian Fischer'],
#  ['Julia Tonne', 'Frank Schmidt'],
#  ['Julia Tonne', 'Olaf Krenz'],
#  ['Jens Rosenkranz', 'Thomas Haegeler'],
#  ['Jana Brechlin', 'Manuel Niemann'],
#  ['Ekkehard Schulreich', 'Nikos Natsidis', 'Olaf Krenz', 'Julia Tonne'],
#  ['Frank Prenzel', 'Haig Latchinian', 'Frank Pfeifer'],
#  ['Dirk Wurzel', 'Thomas Sparrer'],
#  ['Heike Liesaus', 'Kathrin Kabelitz'],
#  ['Nikos Natsidis', 'Julia Tonne', 'Ekkehard Schulreich', 'Olaf Krenz'],
#  ['Simone Prenzel', 'Frank Schmidt'],
#  ['Axel Kaminski', 'Manuel Niemann'],
#  ['Heike Liesaus', 'Christian Kunze', 'Manuel Niemann'],
#  ['Kathrin Kabelitz', 'Nico Fliegner'],
#  ['Nikos Natsidis', 'Frank Pfeifer'],
#  ['Gislinde Redepenning', 'Olaf Barth'],
#  ['Heike Liesaus', 'Ilka Fischer'],
#  ['Julia Tonne', 'Nikos Natsidis'],
#  ['Ekkehard Schulreich', 'Frank Pfeifer'],
#  ['Christine Jacob', 'Ilka Fischer', 'Steffen Brost'],
#  ['Julia Tonne', 'Ekkehard Schulreich', 'Simone Prenzel'],
#  ['Axel Kaminski', 'Manuel Niemann'],
#  ['Frank Schmidt', 'Julia Tonne'],
#  ['Julia Tonne', 'Olaf Krenz'],
#  ['Axel Kaminski', 'Manuel Niemann'],
#  ['Ekkehard Schulreich', 'Olaf Krenz'],
#  ['Christian Kunze', 'Manuel Niemann'],
#  ['Julia Tonne', 'Nikos Natsidis'],
#  ['Nico Fliegner', 'Ilka Fischer'],
#  ['Kathrin Kabelitz', 'Heike Liesaus'],
#  ['Steffi Robak', 'Dirk Wurzel'],
#  ['Ilka Fischer', 'Simone Prenzel'],
#  ['Christine Jacob', 'Heike Liesaus'],
#  ['Julia Tonne', 'Simone Prenzel'],
#  ['Nico Fliegner', 'Steffen Brost', 'Kathrin Kabelitz'],
#  ['Christine Jacob', 'Heike Liesaus'],
#  ['Steffi Robak', 'Thomas Sparrer'],
#  ['Frank Prenzel', 'Kai-Uwe Brandt', 'Haig Latchinian'],
#  ['Simone Prenzel', 'Frank Prenzel'],
#  ['Christian Kunze', 'Manuel Niemann'],
#  ['Nico Fliegner', 'Steffen Brost'],
#  ['Frank Prenzel', 'Kai-Uwe Brandt', 'Haig Latchinian'],
#  ['Nico Fliegner', 'Steffen Brost'],
#  ['Julia Tonne', 'Olaf Krenz', 'Frank Prenzel'],
#  ['Axel Kaminski', 'Manuel Niemann'],
#  ['Christine Jacob', 'Nico Fliegner'],
#  ['Simone Prenzel', 'Julia Tonne', 'Thomas Haegeler'],
#  ['Kai-Uwe Brandt', 'Frank Prenzel'],
#  ['Jana Brechlin', 'Manuel Niemann'],
#  ['Julia Tonne', 'Olaf Krenz'],
#  ['Dirk Wurzel', 'Steffi Robak'],
#  ['Ekkehard Schulreich', 'Frank Schmidt'],
#  ['Jens Rosenkranz', 'Thomas Haegeler'],
#  ['Jens Rosenkranz', 'Thomas Haegeler'],
#  ['Thomas Haegeler', 'Jens Rosenkranz'],
#  ['Dirk Wurzel', 'Thomas Sparrer'],
#  ['Dirk Wurzel', 'Thomas Sparrer'],
#  ['Frank Schmidt', 'Thomas Haegeler'],
#  ['Thomas Sparrer', 'Bastian Fischer', 'Nikos Natsidis'],
#  ['Frank Prenzel', 'Olaf Krenz'],
#  ['Nikos Natsidis', 'Ekkehard Schulreich'],
#  ['Ekkehard Schulreich', 'Frank Pfeifer', 'Nikos Natsidis'],
#  ['Nico Fliegner', 'Jana Brechlin'],
#  ['Steffen Brost', 'Nico Fliegner'],
#  ['Matthias Roth', 'Andreas Tappert'],
#  ['Axel Kaminski', 'Jana Brechlin'],
#  ['Ekkehard Schulreich', 'Thomas Haegeler'],
#  ['Frank Schmidt', 'Ekkehard Schulreich', 'Julia Tonne', 'Nikos Natsidis'],
#  ['Thomas Haegeler', 'Jens Rosenkranz'],
#  ['Matthias Roth', 'Thomas Sparrer'],
#  ['Jens Rosenkranz', 'Thomas Haegeler'],
#  ['Olaf Krenz', 'Ekkehard Schulreich', 'Julia Tonne'],
#  ['Matthias Roth', 'Gislinde Redepenning'],
#  ['Thomas Sparrer', 'Dirk Wurzel'],
#  ['Thomas Sparrer', 'Simone Prenzel'],
#  ['Heike Liesaus', 'Christine Jacob'],
#  ['Christian Kunze', 'Manuel Niemann', 'Axel Kaminski'],
#  ['Dirk Wurzel', 'Thomas Sparrer'],
#  ['Heike Liesaus', 'Ilka Fischer', 'Kathrin Kabelitz'],
#  ['Heike Liesaus', 'Nico Fliegner', 'Steffen Brost'],
#  ['Simone Prenzel', 'Olaf Krenz'],
#  ['Matthias Roth', 'Matthias Puppe'],
#  ['Steffi Robak', 'Dirk Wurzel'],
#  ['Thomas Haegeler', 'Jens Rosenkranz'],
#  ['Thomas Haegeler', 'Jens Rosenkranz'],
#  ['Jens Rosenkranz', 'Thomas Haegeler'],
#  ['Thomas Haegeler', 'Jens Rosenkranz'],
#  ['Heike Liesaus', 'Christine Jacob'],
#  ['Matthias Roth', 'Matthias Puppe'],
#  ['Matthias Roth', 'Jens Rometsch'],
#  ['Thomas Haegeler', 'Jens Rosenkranz'],
#  ['Julia Tonne', 'Nikos Natsidis'],
#  ['Matthias Roth', 'Jens Rometsch'],
#  ['Ekkehard Schulreich', 'Julia Tonne'],
#  ['Julia Tonne', 'Simone Prenzel'],
#  ['Steffen Brost', 'Kathrin Kabelitz'],
#  ['Christine Jacob', 'Olaf Krenz', 'Julia Tonne'],
#  ['Frank Schmidt', 'Julia Tonne', 'Olaf Krenz'],
#  ['Jens Rosenkranz', 'Thomas Sparrer'],
#  ['Matthias Roth', 'Kai-Uwe Brandt'],
#  ['Axel Kaminski', 'Manuel Niemann'],
#  ['Nico Fliegner', 'Ilka Fischer'],
#  ['Jens Rosenkranz', 'Steffi Robak'],
#  ['Jens Rosenkranz', 'Matthias Roth'],
#  ['Matthias Roth', 'Thomas Sparrer'],
#  ['Christian Kunze', 'Axel Kaminski'],
#  ['Matthias Roth', 'Jens Rometsch'],
#  ['Frank Schmidt', 'Julia Tonne'],
#  ['Thomas Haegeler', 'Jens Rosenkranz'],
#  ['Christine Jacob', 'Heike Liesaus'],
#  ['Steffen Brost', 'Kathrin Kabelitz'],
#  ['Dirk Wurzel', 'Thomas Sparrer'],
#  ['Thomas Haegeler', 'Thomas Sparrer'],
#  ['Kathrin Kabelitz', 'Ilka Fischer'],
#  ['Kathrin Kabelitz', 'Nico Fliegner'],
#  ['Ilka Fischer', 'Steffen Brost'],
#  ['Matthias Roth', 'Thomas Haegeler', 'Bastian Fischer'],
#  ['Axel Kaminski', 'Matthias Roth'],
#  ['Jens Rometsch', 'Matthias Roth'],
#  ['Heike Liesaus', 'Christine Jacob'],
#  ['Olaf Krenz', 'Julia Tonne'],
#  ['Christine Jacob', 'Heike Liesaus'],
#  ['Roger Dietze', 'Frank Pfeifer'],
#  ['Heike Liesaus', 'Christine Jacob'],
#  ['Kathrin Kabelitz', 'Steffen Brost'],
#  ['Frank Prenzel', 'Kai-Uwe Brandt'],
#  ['Julia Tonne', 'Olaf Krenz'],
#  ['Kathrin Kabelitz', 'Steffen Brost'],
#  ['Nico Fliegner', 'Ilka Fischer'],
#  ['Kathrin Kabelitz', 'Steffen Brost'],
#  ['Frank Prenzel', 'Ekkehard Schulreich'],
#  ['Matthias Roth', 'Matthias Puppe'],
#  ['Axel Kaminski', 'Manuel Niemann'],
#  ['Ilka Fischer', 'Kathrin Kabelitz'],
#  ['Frank Schmidt', 'Roger Dietze'],
#  ['Jens Rosenkranz', 'Thomas Haegeler'],
#  ['Jens Rosenkranz', 'Thomas Haegeler'],
#  ['Matthias Roth', 'Matthias Puppe'],
#  ['Olaf Krenz', 'Nikos Natsidis'],
#  ['Jens Rosenkranz', 'Thomas Haegeler'],
#  ['Ilka Fischer', 'Nico Fliegner'],
#  ['Christine Jacob', 'Kathrin Kabelitz', 'Nico Fliegner'],
#  ['Kathrin Kabelitz', 'Christine Jacob', 'Nico Fliegner'],
#  ['Kathrin Kabelitz', 'Christine Jacob', 'Nico Fliegner'],
#  ['Christine Jacob', 'Heike Liesaus'],
#  ['Jens Rosenkranz', 'Thomas Haegeler'],
#  ['Thomas Haegeler', 'Jens Rosenkranz'],
#  ['Mathias Orbeck', 'Andreas Tappert'],
#  ['Mathias Orbeck', 'Andreas Tappert'],
#  ['Mathias Orbeck', 'Andreas Tappert'],
#  ['Thomas Haegeler', 'Jens Rosenkranz'],
#  ['Mathias Orbeck', 'Andreas Tappert'],
#  ['Thomas Haegeler', 'Jens Rosenkranz'],
#  ['Christine Jacob', 'Heike Liesaus'],
#  ['Thomas Haegeler', 'Jens Rosenkranz'],
#  ['Matthias Puppe', 'Christine Jacob', 'Olaf Krenz'],
#  ['Thomas Haegeler', 'Jens Rosenkranz'],
#  ['Kathrin Kabelitz', 'Christine Jacob'],
#  ['Thomas Haegeler', 'Kai-Uwe Brandt', 'Nikos Natsidis'],
#  ['Bastian Fischer', 'Thomas Haegeler'],
#  ['Kathrin Kabelitz', 'Steffen Brost'],
#  ['Haig Latchinian', 'Julia Tonne'],
#  ['Nikos Natsidis', 'Julia Tonne'],
#  ['Jana Brechlin', 'Axel Kaminski', 'Manuel Niemann'],
#  ['Andreas Tappert', 'Mathias Orbeck'],
#  ['Thomas Sparrer', 'Dirk Wurzel'],
#  ['Steffen Brost', 'Kathrin Kabelitz'],
#  ['Frank Schmidt', 'Olaf Krenz', 'Ekkehard Schulreich', 'Julia Tonne'],
#  ['Christian Kunze', 'Axel Kaminski'],
#  ['Thomas Haegeler', 'Jens Rosenkranz'],
#  ['Nico Fliegner', 'Kathrin Kabelitz'],
#  ['Jens Rosenkranz', 'Thomas Haegeler'],
#  ['Thomas Haegeler', 'Jens Rosenkranz'],
#  ['Manuel Niemann', 'Axel Kaminski'],
#  ['Julia Tonne',
#   'Frank Prenzel',
#   'Kai-Uwe Brandt',
#   'Olaf Krenz',
#   'Ekkehard Schulreich'],
#  ['Simone Prenzel', 'Olaf Krenz'],
#  ['Matthias Roth', 'Frank Schmidt'],
#  ['Thomas Haegeler', 'Steffi Robak'],
#  ['Jana Brechlin', 'Axel Kaminski'],
#  ['Andreas Tappert', 'Jens Rometsch'],
#  ['Matthias Puppe', 'Simone Prenzel'],
#  ['Jens Rosenkranz', 'Thomas Haegeler'],
#  ['Kathrin Kabelitz', 'Steffen Brost'],
#  ['Matthias Puppe', 'Thomas Sparrer'],
#  ['Matthias Puppe', 'Matthias Roth'],
#  ['Matthias Puppe', 'Thomas Sparrer'],
#  ['Manuel Niemann', 'Axel Kaminski'],
#  ['Haig Latchinian', 'Julia Tonne'],
#  ['Kathrin Kabelitz', 'Nico Fliegner'],
#  ['Heike Liesaus', 'Nico Fliegner'],
#  ['Andreas Tappert', 'Mathias Orbeck'],
#  ['Kathrin Kabelitz', 'Steffen Brost'],
#  ['Kathrin Kabelitz', 'Nico Fliegner'],
#  ['Nico Fliegner', 'Kathrin Kabelitz'],
#  ['Nico Fliegner', 'Kathrin Kabelitz'],
#  ['Ekkehard Schulreich', 'Frank Schmidt'],
#  ['Frank Schmidt', 'Jens Rosenkranz'],
#  ['Dirk Wurzel', 'Thomas Sparrer'],
#  ['Heike Liesaus', 'Christine Jacob'],
#  ['Olaf Krenz', 'Bastian Fischer'],
#  ['Kathrin Kabelitz', 'Nico Fliegner'],
#  ['Jana Brechlin', 'Axel Kaminski'],
#  ['Jana Brechlin', 'Axel Kaminski'],
#  ['Jens Rosenkranz', 'Thomas Haegeler'],
#  ['Kathrin Kabelitz', 'Steffen Brost'],
#  ['Heike Liesaus', 'Christine Jacob'],
#  ['Steffen Brost', 'Nico Fliegner'],
#  ['Thomas Haegeler', 'Jens Rosenkranz'],
#  ['Mathias Orbeck', 'Andreas Tappert'],
#  ['Kathrin Kabelitz', 'Manuel Niemann'],
#  ['Steffen Brost', 'Ilka Fischer'],
#  ['Matthias Roth', 'Matthias Puppe'],
#  ['Mathias Orbeck', 'Evelyn ter Vehn'],
#  ['Matthias Roth', 'Matthias Puppe'],
#  ['Matthias Roth', 'Matthias Puppe'],
#  ['Jana Brechlin', 'Axel Kaminski'],
#  ['Evelyn ter Vehn', 'Matthias Puppe'],
#  ['Matthias Roth', 'Matthias Puppe'],
#  ['Matthias Puppe', 'Thomas Haegeler'],
#  ['Frank Prenzel', 'Simone Prenzel'],
#  ['Olaf Barth', 'Roland Heinrich'],
#  ['Julia Tonne', 'Olaf Krenz'],
#  ['Kai-Uwe Brandt', 'Matthias Puppe'],
#  ['Kathrin Kabelitz', 'Christine Jacob'],
#  ['Ekkehard Schulreich', 'Evelyn ter Vehn'],
#  ['Steffen Brost', 'Kathrin Kabelitz', 'Christine Jacob'],
#  ['Thomas Haegeler', 'Jens Rosenkranz'],
#  ['Bastian Fischer', 'Thomas Haegeler'],
#  ['Frank Schmidt', 'Ekkehard Schulreich'],
#  ['Mathias Orbeck', 'Matthias Puppe'],
#  ['Christine Jacob', 'Ilka Fischer', 'Steffen Brost'],
#  ['Kathrin Kabelitz', 'Ilka Fischer'],
#  ['Evelyn ter Vehn', 'Matthias Roth'],
#  ['Matthias Roth', 'Andreas Tappert'],
#  ['Evelyn ter Vehn', 'Evelyn ter Vehn'],
#  ['Simone Prenzel', 'Nikos Natsidis', 'Ekkehard Schulreich'],
#  ['Christine Jacob', 'Heike Liesaus'],
#  ['Ekkehard Schulreich', 'Frank Pfeifer'],
#  ['Matthias Puppe', 'Matthias Roth'],
#  ['Matthias Roth', 'Ekkehard Schulreich'],
#  ['Kathrin Kabelitz', 'Christine Jacob'],
#  ['Thomas Sparrer', 'Manuel Niemann'],
#  ['Ekkehard Schulreich', 'Matthias Puppe'],
#  ['Manuel Niemann', 'Andreas Tappert'],
#  ['Andreas Tappert', 'Mathias Orbeck'],
#  ['Andreas Tappert', 'Jens Rometsch'],
#  ['Heike Liesaus', 'Simone Prenzel'],
#  ['Christian Kunze', 'Axel Kaminski'],
#  ['Heike Liesaus', 'Kathrin Kabelitz'],
#  ['Nikos Natsidis', 'Julia Tonne'],
#  ['Evelyn ter Vehn', 'Jens Rosenkranz'],
#  ['Kathrin Kabelitz', 'Steffen Brost'],
#  ['Jana Brechlin', 'Axel Kaminski'],
#  ['Jana Brechlin', 'Axel Kaminski'],
#  ['Matthias Puppe', 'Ekkehard Schulreich'],
#  ['Simone Prenzel', 'Julia Tonne'],
#  ['Julia Tonne', 'Olaf Krenz'],
#  ['Evelyn ter Vehn', 'Matthias Puppe'],
#  ['Evelyn ter Vehn', 'Matthias Puppe'],
#  ['Andreas Tappert', 'Evelyn ter Vehn'],
#  ['Matthias Puppe', 'Evelyn ter Vehn'],
#  ['Jens Rosenkranz', 'Thomas Haegeler'],
#  ['Thomas Haegeler', 'Jens Rosenkranz'],
#  ['Evelyn ter Vehn', 'Matthias Puppe'],
#  ['Jens Rosenkranz', 'Thomas Haegeler'],
#  ['Thomas Haegeler', 'Jens Rosenkranz'],
#  ['Kathrin Kabelitz', 'Heike Liesaus', 'Ilka Fischer'],
#  ['Jens Rosenkranz', 'Thomas Haegeler'],
#  ['Kathrin Kabelitz', 'Steffen Brost'],
#  ['Thomas Haegeler', 'Jens Rosenkranz'],
#  ['Jens Rosenkranz', 'Thomas Haegeler'],
#  ['Matthias Roth', 'Jens Rometsch'],
#  ['Evelyn ter Vehn', 'Olaf Barth'],
#  ['Jana Brechlin', 'Axel Kaminski'],
#  ['Ekkehard Schulreich', 'Julia Tonne'],
#  ['Jens Rosenkranz', 'Evelyn ter Vehn'],
#  ['Kathrin Kabelitz', 'Ilka Fischer'],
#  ['Evelyn ter Vehn', 'Jens Rosenkranz'],
#  ['Thomas Haegeler', 'Jens Rosenkranz'],
#  ['Matthias Puppe', 'Ekkehard Schulreich'],
#  ['Simone Prenzel', 'Olaf Krenz'],
#  ['Kathrin Kabelitz', 'Christine Jacob'],
#  ['Julia Tonne', 'Simone Prenzel'],
#  ['Simone Prenzel', 'Nikos Natsidis'],
#  ['Andreas Tappert', 'Jens Rometsch'],
#  ['Christian Kunze', 'Christine Jacob'],
#  ['Axel Kaminski', 'Nikos Natsidis'],
#  ['Thomas Haegeler', 'Jens Rosenkranz'],
#  ['Kai-Uwe Brandt', 'Frank Schmidt'],
#  ['Evelyn ter Vehn', 'Matthias Puppe'],
#  ['Ekkehard Schulreich', 'Simone Prenzel', 'Nikos Natsidis', 'Frank Prenzel'],
#  ['Evelyn ter Vehn', 'Matthias Roth'],
#  ['Thomas Sparrer', 'Manuel Niemann', 'Dirk Wurzel'],
#  ['Ekkehard Schulreich', 'Frank Schmidt'],
#  ['Steffen Brost', 'Kathrin Kabelitz'],
#  ['Frank Prenzel', 'Simone Prenzel'],
#  ['Matthias Roth', 'Jens Rosenkranz'],
#  ['Haig Latchinian', 'Kai-Uwe Brandt'],
#  ['Steffi Robak', 'Dirk Wurzel', 'Manuel Niemann'],
#  ['Evelyn ter Vehn', 'Matthias Puppe'],
#  ['Matthias Roth', 'Matthias Puppe'],
#  ['Andreas Tappert', 'Roland Heinrich'],
#  ['Dirk Wurzel', 'Thomas Sparrer', 'Manuel Niemann'],
#  ['Evelyn ter Vehn', 'Thomas Haegeler'],
#  ['Steffen Brost',
#   'Kathrin Kabelitz',
#   'Christine Jacob',
#   'Heike Liesaus',
#   'Ilka Fischer'],
#  ['Bastian Fischer', 'Thomas Haegeler', 'Jens Rosenkranz'],
#  ['Jens Rosenkranz', 'Thomas Haegeler'],
#  ['Olaf Krenz', 'Bastian Fischer'],
#  ['Nico Fliegner', 'Heike Liesaus'],
#  ['Frank Schmidt', 'Ekkehard Schulreich'],
#  ['Manuel Niemann', 'Christine Jacob'],
#  ['Ilka Fischer', 'Manuel Niemann'],
#  ['Andreas Tappert', 'Thomas Sparrer'],
#  ['Bastian Fischer', 'Jens Rosenkranz'],
#  ['Matthias Puppe', 'Andreas Tappert'],
#  ['Kathrin Kabelitz', 'Heike Liesaus'],
#  ['Thomas Haegeler', 'Jens Rosenkranz'],
#  ['Steffen Brost', 'Heike Liesaus'],
#  ['Christine Jacob', 'Roland Heinrich'],
#  ['Matthias Roth', 'Matthias Puppe'],
#  ['Matthias Puppe', 'Axel Kaminski'],
#  ['Matthias Roth', 'Matthias Puppe'],
#  ['Christian Kunze', 'Axel Kaminski', 'Jana Brechlin'],
#  ['Christian Kunze', 'Axel Kaminski'],
#  ['Christine Jacob', 'Kathrin Kabelitz'],
#  ['Jens Rosenkranz', 'Thomas Haegeler'],
#  ['Manuel Niemann', 'Jens Rosenkranz'],
#  ['Jens Rosenkranz', 'Evelyn ter Vehn'],
#  ['Christian Kunze', 'Axel Kaminski'],
#  ['Thomas Haegeler', 'Jens Rosenkranz'],
#  ['Thomas Haegeler', 'Jens Rosenkranz'],
#  ['Axel Kaminski', 'Christian Kunze'],
#  ['Christine Jacob', 'Steffen Brost', 'Kathrin Kabelitz'],
#  ['Axel Kaminski', 'Jana Brechlin'],
#  ['Kathrin Kabelitz', 'Heike Liesaus'],
#  ['Haig Latchinian', 'Frank Prenzel'],
#  ['Jens Rosenkranz', 'Thomas Haegeler'],
#  ['Jens Rometsch', 'Matthias Roth'],
#  ['Thomas Haegeler', 'Jens Rosenkranz'],
#  ['Manuel Niemann', 'Christian Kunze'],
#  ['Jens Rometsch', 'Mathias Orbeck'],
#  ['Axel Kaminski', 'Christian Kunze'],
#  ['Christine Jacob', 'Nico Fliegner'],
#  ['Bastian Fischer', 'Thomas Haegeler'],
#  ['Simone Prenzel', 'Nikos Natsidis'],
#  ['Steffi Robak', 'Dirk Wurzel'],
#  ['Simone Prenzel', 'Nikos Natsidis', 'Kai-Uwe Brandt', 'Thomas Haegeler'],
#  ['Christine Jacob', 'Nico Fliegner'],
#  ['Olaf Krenz', 'Ekkehard Schulreich'],
#  ['Julia Tonne', 'Ekkehard Schulreich'],
#  ['Matthias Roth', 'Matthias Puppe'],
#  ['Steffen Brost', 'Nico Fliegner'],
#  ['Heike Liesaus', 'Kathrin Kabelitz'],
#  ['Andreas Tappert', 'Evelyn ter Vehn'],
#  ['Thomas Sparrer', 'Steffi Robak'],
#  ['Matthias Puppe', 'Ekkehard Schulreich'],
#  ['Jens Rosenkranz', 'Bastian Fischer'],
#  ['Simone Prenzel', 'Frank Prenzel'],
#  ['Julia Tonne', 'Nikos Natsidis'],
#  ['Thomas Haegeler', 'Jens Rosenkranz'],
#  ['Haig Latchinian', 'Kai-Uwe Brandt'],
#  ['Nikos Natsidis', 'Julia Tonne'],
#  ['Jana Brechlin', 'Axel Kaminski'],
#  ['Christian Kunze', 'Axel Kaminski'],
#  ['Manuel Niemann', 'Axel Kaminski'],
#  ['Evelyn ter Vehn', 'Jens Rosenkranz'],
#  ['Evelyn ter Vehn', 'Matthias Roth'],
#  ['Christine Jacob', 'Manuel Niemann'],
#  ['Jens Rosenkranz', 'Thomas Haegeler'],
#  ['Kathrin Kabelitz', 'Ilka Fischer'],
#  ['Matthias Roth', 'Matthias Puppe'],
#  ['Ilka Fischer', 'Kathrin Kabelitz'],
#  ['Evelyn ter Vehn', 'Thomas Haegeler'],
#  ['Jana Brechlin', 'Axel Kaminski'],
#  ['Olaf Krenz', 'Julia Tonne'],
#  ['Kathrin Kabelitz', 'Ilka Fischer'],
#  ['Christine Jacob', 'Kathrin Kabelitz'],
#  ['Matthias Roth', 'Matthias Puppe'],
#  ['Christine Jacob', 'Manuel Niemann'],
#  ['Jens Rosenkranz', 'Matthias Puppe'],
#  ['Jens Rosenkranz', 'Matthias Roth'],
#  ['Evelyn ter Vehn', 'Jens Rosenkranz'],
#  ['Matthias Puppe', 'Evelyn ter Vehn'],
#  ['Julia Tonne', 'Olaf Krenz'],
#  ['Matthias Puppe', 'Thomas Haegeler'],
#  ['Thomas Haegeler', 'Matthias Puppe'],
#  ['Simone Prenzel', 'Julia Tonne'],
#  ['Kathrin Kabelitz', 'Steffen Brost'],
#  ['Haig Latchinian', 'Frank Pfeifer'],
#  ['Kai-Uwe Brandt', 'Christine Jacob'],
#  ['Evelyn ter Vehn', 'Thomas Haegeler'],
#  ['Matthias Puppe', 'Jens Rosenkranz'],
#  ['Christine Jacob', 'Kathrin Kabelitz'],
#  ['Evelyn ter Vehn', 'Matthias Puppe'],
#  ['Jens Rosenkranz', 'Evelyn ter Vehn'],
#  ['Nico Fliegner', 'Ilka Fischer'],
#  ['Nico Fliegner', 'Ilka Fischer'],
#  ['Nikos Natsidis', 'Julia Tonne'],
#  ['Steffen Brost', 'Kathrin Kabelitz'],
#  ['Kathrin Kabelitz', 'Ilka Fischer'],
#  ['Matthias Puppe', 'Jens Rosenkranz'],
#  ['Christine Jacob', 'Manuel Niemann'],
#  ['Jens Rosenkranz', 'Bastian Fischer'],
#  ['Jens Rosenkranz', 'Thomas Haegeler'],
#  ['Christine Jacob', 'Manuel Niemann'],
#  ['Ilka Fischer', 'Steffen Brost'],
#  ['Evelyn ter Vehn', 'Jens Rosenkranz'],
#  ['Evelyn ter Vehn', 'Jens Rosenkranz'],
#  ['Evelyn ter Vehn', 'Jens Rosenkranz'],
#  ['Manuel Niemann', 'Christian Kunze'],
#  ['Simone Prenzel', 'Thomas Haegeler'],
#  ['Thomas Haegeler', 'Simone Prenzel', 'Ekkehard Schulreich'],
#  ['Heike Liesaus', 'Christine Jacob', 'Kai-Uwe Brandt', 'Thomas Sparrer'],
#  ['Jens Rosenkranz', 'Thomas Haegeler'],
#  ['Christine Jacob', 'Matthias Puppe'],
#  ['Simone Prenzel', 'Frank Schmidt'],
#  ['Kathrin Kabelitz', 'Steffen Brost'],
#  ['Andreas Tappert', 'Roland Heinrich'],
#  ['Jens Rosenkranz', 'Thomas Haegeler'],
#  ['Jens Rosenkranz', 'Evelyn ter Vehn'],
#  ['Matthias Roth', 'Matthias Puppe'],
#  ['Jens Rosenkranz', 'Matthias Puppe'],
#  ['Matthias Roth', 'Matthias Puppe'],
#  ['Matthias Roth', 'Jens Rosenkranz'],
#  ['Heike Liesaus', 'Kathrin Kabelitz'],
#  ['Matthias Puppe', 'Evelyn ter Vehn'],
#  ['Kathrin Kabelitz', 'Heike Liesaus'],
#  ['Andreas Tappert', 'Jens Rometsch'],
#  ['Kathrin Kabelitz', 'Heike Liesaus'],
#  ['Andreas Tappert', 'Matthias Puppe'],
#  ['Mathias Orbeck', 'Andreas Tappert'],
#  ['Matthias Puppe', 'Evelyn ter Vehn', 'Matthias Roth', 'Jens Rosenkranz'],
#  ['Christine Jacob', 'Manuel Niemann'],
#  ['Ilka Fischer', 'Steffen Brost'],
#  ['Dirk Wurzel', 'Frank Pfeifer'],
#  ['Simone Prenzel', 'Ekkehard Schulreich', 'Julia Tonne'],
#  ['Matthias Puppe', 'Evelyn ter Vehn'],
#  ['Matthias Puppe', 'Thomas Haegeler'],
#  ['Kathrin Kabelitz', 'Christian Kunze'],
#  ['Heike Liesaus', 'Kathrin Kabelitz'],
#  ['Jens Rosenkranz', 'Matthias Puppe'],
#  ['Ekkehard Schulreich', 'Olaf Krenz', 'Julia Tonne', 'Thomas Haegeler'],
#  ['Matthias Roth', 'Jens Rosenkranz'],
#  ['Jens Rosenkranz', 'Thomas Haegeler'],
#  ['Ilka Fischer', 'Heike Liesaus'],
#  ['Steffen Brost', 'Manuel Niemann'],
#  ['Steffen Brost', 'Ilka Fischer'],
#  ['Thomas Haegeler', 'Jens Rosenkranz'],
#  ['Ekkehard Schulreich', 'Olaf Krenz'],
#  ['Evelyn ter Vehn', 'Andreas Tappert'],
#  ['Gislinde Redepenning', 'Julia Tonne'],
#  ['Thomas Haegeler', 'Jens Rosenkranz'],
#  ['Thomas Haegeler', 'Ekkehard Schulreich', 'Simone Prenzel'],
#  ['Heike Liesaus', 'Kathrin Kabelitz'],
#  ['Frank Schmidt', 'Matthias Puppe'],
#  ['Steffen Brost', 'Kathrin Kabelitz'],
#  ['Frank Schmidt', 'Kai-Uwe Brandt'],
#  ['Jens Rosenkranz', 'Evelyn ter Vehn'],
#  ['Jens Rosenkranz', 'Thomas Haegeler'],
#  ['Dirk Wurzel', 'Thomas Sparrer'],
#  ['Axel Kaminski', 'Christian Kunze', 'Steffen Brost'],
#  ['Christine Jacob', 'Christian Kunze'],
#  ['Kathrin Kabelitz', 'Steffen Brost'],
#  ['Matthias Puppe', 'Dirk Wurzel'],
#  ['Nikos Natsidis', 'Frank Schmidt'],
#  ['Ekkehard Schulreich', 'Olaf Krenz'],
#  ['Frank Pfeifer', 'Evelyn ter Vehn'],
#  ['Heike Liesaus', 'Ilka Fischer'],
#  ['Kathrin Kabelitz', 'Heike Liesaus'],
#  ['Thomas Sparrer', 'Steffi Robak'],
#  ['Frank Schmidt', 'Kai-Uwe Brandt'],
#  ['Nikos Natsidis', 'Ekkehard Schulreich', 'Julia Tonne'],
#  ['Jens Rometsch', 'Matthias Roth'],
#  ['Kathrin Kabelitz', 'Heike Liesaus', 'Ilka Fischer'],
#  ['Jens Rosenkranz', 'Matthias Puppe'],
#  ['Jens Rosenkranz', 'Thomas Haegeler'],
#  ['Christine Jacob', 'Kathrin Kabelitz'],
#  ['Kathrin Kabelitz', 'Heike Liesaus'],
#  ['Matthias Roth', 'Evelyn ter Vehn'],
#  ['Evelyn ter Vehn', 'Matthias Roth'],
#  ['Matthias Puppe', 'Frank Schmidt'],
#  ['Kathrin Kabelitz', 'Heike Liesaus'],
#  ['Nikos Natsidis', 'Jana Brechlin'],
#  ['Ekkehard Schulreich', 'Thomas Haegeler'],
#  ['Evelyn ter Vehn', 'Matthias Puppe'],
#  ['Kathrin Kabelitz', 'Christine Jacob', 'Heike Liesaus'],
#  ['Christine Jacob', 'Kathrin Kabelitz'],
#  ['Kathrin Kabelitz', 'Steffen Brost'],
#  ['Evelyn ter Vehn', 'Andreas Tappert'],
#  ['Frank Pfeifer', 'Kai-Uwe Brandt'],
#  ['Jana Brechlin', 'Axel Kaminski'],
#  ['Kai-Uwe Brandt', 'Frank Schmidt'],
#  ['Evelyn ter Vehn', 'Jens Rometsch'],
#  ['Evelyn ter Vehn', 'Axel Kaminski'],
#  ['Andreas Tappert', 'Roland Heinrich'],
#  ['Jens Rosenkranz', 'Thomas Haegeler'],
#  ['Kathrin Kabelitz', 'Heike Liesaus'],
#  ['Evelyn ter Vehn', 'Matthias Puppe'],
#  ['Frank Pfeifer', 'Ekkehard Schulreich'],
#  ['Kathrin Kabelitz', 'Heike Liesaus'],
#  ['Kathrin Kabelitz', 'Steffen Brost'],
#  ['Kathrin Kabelitz', 'Steffen Brost'],
#  ['Ekkehard Schulreich', 'Thomas Haegeler'],
#  ['Ilka Fischer', 'Steffen Brost'],
#  ['Ilka Fischer', 'Kathrin Kabelitz'],
#  ['Ulrike Witt', 'Matthias Roth'],
#  ['Heike Liesaus', 'Kathrin Kabelitz'],
#  ['Steffi Robak', 'Frank Schmidt'],
#  ['Matthias Roth', 'Evelyn ter Vehn'],
#  ['Thomas Haegeler', 'Jens Rosenkranz'],
#  ['Jens Rosenkranz', 'Matthias Puppe'],
#  ['Ilka Fischer', 'Nico Fliegner'],
#  ['Nico Fliegner', 'Matthias Puppe'],
#  ['Axel Kaminski', 'Frank Schmidt'],
#  ['Dirk Wurzel', 'Thomas Sparrer'],
#  ['Matthias Roth', 'Matthias Puppe'],
#  ['Evelyn ter Vehn', 'Matthias Puppe'],
#  ['Dirk Wurzel', 'Thomas Sparrer'],
#  ['Julia Tonne', 'Ekkehard Schulreich'],
#  ['Kathrin Kabelitz', 'Heike Liesaus'],
#  ['Matthias Puppe', 'Evelyn ter Vehn'],
#  ['Evelyn ter Vehn', 'Andreas Tappert'],
#  ['Matthias Puppe', 'Jens Rosenkranz'],
#  ['Jens Rosenkranz', 'Evelyn ter Vehn'],
#  ['Jens Rosenkranz', 'Matthias Puppe'],
#  ['Matthias Puppe', 'Evelyn ter Vehn'],
#  ['Matthias Puppe', 'Evelyn ter Vehn'],
#  ['Christine Jacob', 'Nico Fliegner'],
#  ['Jens Rosenkranz', 'Matthias Puppe'],
#  ['Ilka Fischer', 'Nico Fliegner'],
#  ['Heike Liesaus', 'Ilka Fischer'],
#  ['Jens Rometsch', 'Matthias Roth'],
#  ['Jens Rosenkranz', 'Matthias Puppe'],
#  ['Olaf Barth', 'Roland Heinrich'],
#  ['Olaf Barth', 'Evelyn ter Vehn'],
#  ['Olaf Barth', 'Evelyn ter Vehn'],
#  ['Evelyn ter Vehn', 'Matthias Puppe'],
#  ['Matthias Puppe', 'Jens Rometsch'],
#  ['Frank Pfeifer', 'Nikos Natsidis'],
#  ['Jens Rometsch', 'Jens Rosenkranz'],
#  ['Kerstin Decker', 'Evelyn ter Vehn'],
#  ['Evelyn ter Vehn', 'Matthias Roth'],
#  ['Matthias Roth', 'Evelyn ter Vehn'],
#  ['Ekkehard Schulreich', 'Evelyn ter Vehn'],
#  ['Evelyn ter Vehn', 'Jens Rosenkranz'],
#  ['Evelyn ter Vehn', 'Matthias Puppe'],
#  ['Ekkehard Schulreich', 'Matthias Roth'],
#  ['Evelyn ter Vehn', 'Jens Rosenkranz'],
#  ['Evelyn ter Vehn', 'Matthias Puppe'],
#  ['Ekkehard Schulreich', 'Matthias Puppe'],
#  ['Evelyn ter Vehn', 'Jens Rosenkranz'],
#  ['Evelyn ter Vehn', 'Jens Rosenkranz'],
#  ['Jens Rosenkranz', 'Matthias Puppe'],
#  ['Evelyn ter Vehn', 'Matthias Puppe'],
#  ['Matthias Roth', 'Matthias Puppe'],
#  ['Matthias Roth', 'Jens Rometsch'],
#  ['Andreas Tappert', 'Matthias Puppe'],
#  ['Evelyn ter Vehn', 'Matthias Roth'],
#  ['Evelyn ter Vehn', 'Matthias Puppe'],
#  ['Jens Rosenkranz', 'Evelyn ter Vehn'],
#  ['Andreas Tappert', 'Roland Heinrich'],
#  ['Ulrike Witt', 'Julia Tonne'],
#  ['Roger Dietze', 'Frank Prenzel'],
#  ['Mathias Orbeck', 'Matthias Puppe'],
#  ['Andreas Tappert', 'Matthias Puppe'],
#  ['Andreas Tappert', 'Evelyn ter Vehn'],
#  ['Matthias Puppe', 'Jens Rosenkranz'],
#  ['Ekkehard Schulreich', 'Matthias Puppe'],
#  ['Matthias Puppe', 'Jens Rosenkranz'],
#  ['Matthias Roth', 'Dirk Wurzel'],
#  ['Evelyn ter Vehn', 'Matthias Puppe'],
#  ['Matthias Puppe', 'Jens Rosenkranz'],
#  ['Nico Fliegner', 'Steffen Brost'],
#  ['Matthias Puppe', 'Jens Rosenkranz'],
#  ['Matthias Roth', 'Matthias Puppe'],
#  ['Ekkehard Schulreich', 'Matthias Puppe'],
#  ['Matthias Roth', 'Andreas Tappert'],
#  ['Jens Rosenkranz', 'Evelyn ter Vehn'],
#  ['Jens Rosenkranz', 'Evelyn ter Vehn'],
#  ['Matthias Puppe', 'Jens Rosenkranz'],
#  ['Jens Rosenkranz', 'Evelyn ter Vehn'],
#  ['Steffen Brost', 'Nico Fliegner'],
#  ['Matthias Puppe', 'Matthias Roth'],
#  ['Evelyn ter Vehn', 'Matthias Puppe'],
#  ['Nico Fliegner', 'Christine Jacob'],
#  ['Nico Fliegner', 'Steffen Brost'],
#  ['Jens Rosenkranz', 'Matthias Puppe'],
#  ['Evelyn ter Vehn', 'Matthias Roth'],
#  ['Roland Heinrich', 'Olaf Barth'],
#  ['Thomas Haegeler', 'Jens Rosenkranz'],
#  ['Jens Rosenkranz', 'Thomas Haegeler'],
#  ['Haig Latchinian', 'Kerstin Decker'],
#  ['Jens Rosenkranz', 'Matthias Puppe'],
#  ['Evelyn ter Vehn', 'Jens Rosenkranz'],
#  ['Ilka Fischer', 'Nico Fliegner'],
#  ['Kerstin Decker', 'Matthias Puppe'],
#  ['Evelyn ter Vehn', 'Matthias Roth'],
#  ['Ulrike Witt', 'Matthias Puppe'],
#  ['Jens Rosenkranz', 'Matthias Puppe'],
#  ['Evelyn ter Vehn', 'Matthias Puppe'],
#  ['Matthias Puppe', 'Jens Rosenkranz'],
#  ['Jens Rosenkranz', 'Matthias Puppe'],
#  ['Jens Rosenkranz', 'Matthias Puppe'],
#  ['Jens Rosenkranz', 'Matthias Puppe'],
#  ['Nico Fliegner', 'Christine Jacob'],
#  ['Nico Fliegner', 'Steffen Brost'],
#  ['Steffen Brost', 'Nico Fliegner'],
#  ['Matthias Puppe', 'Matthias Roth'],
#  ['Jens Rosenkranz', 'Matthias Puppe'],
#  ['Matthias Puppe', 'Jens Rosenkranz'],
#  ['Olaf Barth', 'Roland Heinrich'],
#  ['Olaf Barth', 'Roland Heinrich'],
#  ['Matthias Puppe', 'Matthias Roth'],
#  ['Nico Fliegner', 'Steffen Brost'],
#  ['Nico Fliegner', 'Steffen Brost'],
#  ['Jens Rosenkranz', 'Evelyn ter Vehn'],
#  ['Jens Rosenkranz', 'Evelyn ter Vehn'],
#  ['Thomas Sparrer', 'Matthias Roth'],
#  ['Jens Rosenkranz', 'Matthias Puppe'],
#  ['Evelyn ter Vehn', 'Matthias Puppe'],
#  ['Heike Liesaus', 'Steffen Brost'],
#  ['Matthias Puppe', 'Jens Rosenkranz'],
#  ['Olaf Barth', 'Roland Heinrich'],
#  ['Matthias Roth', 'Mathias Orbeck'],
#  ['Matthias Roth', 'Evelyn ter Vehn'],
#  ['Jens Rosenkranz', 'Matthias Puppe'],
#  ['Matthias Roth', 'Matthias Puppe'],
#  ['Matthias Puppe', 'Ekkehard Schulreich'],
#  ['Matthias Roth', 'Jens Rosenkranz'],
#  ['Matthias Roth', 'Matthias Puppe'],
#  ['Evelyn ter Vehn', 'Matthias Roth'],
#  ['Dirk Wurzel', 'Thomas Sparrer'],
#  ['Evelyn ter Vehn', 'Simone Prenzel'],
#  ['Matthias Roth', 'Jens Rosenkranz'],
#  ['Matthias Puppe', 'Jens Rosenkranz'],
#  ['Ulrike Witt', 'Nikos Natsidis'],
#  ['Matthias Puppe', 'Matthias Roth'],
#  ['Thomas Sparrer', 'Christine Jacob'],
#  ['Andreas Tappert', 'Matthias Roth'],
#  ['Matthias Puppe', 'Matthias Roth'],
#  ['Christian Kunze', 'Roger Dietze'],
#  ['Nico Fliegner', 'Steffen Brost'],
#  ['Ekkehard Schulreich', 'Matthias Puppe'],
#  ['Thomas Haegeler', 'Jens Rosenkranz'],
#  ['Ekkehard Schulreich', 'Roger Dietze'],
#  ['Nico Fliegner', 'Steffen Brost'],
#  ['Nico Fliegner', 'Steffen Brost'],
#  ['Nico Fliegner', 'Steffen Brost'],
#  ['Jens Rosenkranz', 'Matthias Puppe'],
#  ['Matthias Puppe', 'Jens Rometsch'],
#  ['Ulrike Witt', 'Julia Tonne'],
#  ['Matthias Roth', 'Matthias Puppe'],
#  ['Andreas Tappert', 'Roland Heinrich'],
#  ...]

# %%
# print len edges
print(len(edges))
# Out:
# 1079

# %%
# remove edges with more than 2 names
modified_edges = []
for edge in edges:
    if len(edge) > 2:
        for i in range(len(edge)):
            for j in range(i+1, len(edge)):
                modified_edges.append([edge[i], edge[j]])
    else:
        modified_edges.append(edge)

# %%
edges = modified_edges

# %%
graph = nx.Graph()
graph.clear()

# Count the occurrences of each edge
edge_counts = {}
for edge in edges:
    key = tuple(sorted(edge))
    edge_counts[key] = edge_counts.get(key, 0) + 1

color_map = []

# Add nodes and weighted edges to the graph
for edge, count in edge_counts.items():
    node1, node2 = edge
    if count < 5:
        continue
    if not graph.has_node(node1):
        graph.add_node(node1)
        # add a color to the node
        color_map.append(author_departments[author_departments.name == node1].color.values[0])
    if not graph.has_node(node2):
        graph.add_node(node2)
        # add a color to the node
        color_map.append(author_departments[author_departments.name == node2].color.values[0])
    graph.add_edge(node1, node2, weight=count)

# display graph
plt.figure(figsize=[6, 6])
plt.title('Names connected by co-authorship\n colored by department membership')
nx.draw(graph, node_color=color_map, node_size=100, font_size=6.5, font_weight='bold', edge_color='gray')
# Create a dummy plot for the legend (this won't be visible, but it's necessary to create a legend)
import matplotlib.patches as mpatches
# get department names from author_departments that are in color_map
departments_in_color_map = [author_departments[author_departments.color == color].department.values[0] for color in color_map]
# merge as dict with department name as key and color as value
color_legend_map = dict(zip(departments_in_color_map, color_map))
legend_patches = [mpatches.Patch(color=color, label=label) for label, color in color_legend_map.items()]
plt.legend(handles=legend_patches, title='Department', loc='lower right')
plt.savefig('../reports/figures/department_exploration/names_co_authors_department_membership.png', dpi=200)

# %%
counts = departments.groupby('department').agg('count').sort_values(by='id', ascending=False).head(50).sort_values(by='id', ascending=True)

# %%
counts
# Out:
#                             id  published_at   name
# department
# Familie                     20            20     20
# Coronavirus                 21            21     21
# KWL                         26            26     26
# Achtung-Baustelle           28            28     28
# Fluechtlinge-in-Leipzig     28            28     28
# Hochwasser-in-Sachsen       31            31     31
# Die-Akte-Unister            34            34     34
# Wahl                        39            39     39
# Legida                      43            43     43
# Legida-und-Proteste         49            49     49
# Ausstellungen               63            63     63
# Spielberichte               86            86     86
# 1.-FC-Lok                   93            93     93
# BSG-Chemie                  99            99     99
# Leipziger-Museen           110           110    110
# HC-Leipzig                 154           154    154
# Markranstaedt              191           191    191
# RB-Archiv                  195           195    195
# Wirtschaft-Regional        282           282    282
# Wirtschaft                 285           285    285
# Bildung                    306           306    306
# RB-Leipzig                 386           386    386
# Sport-Regional             405           405    405
# SC-DHfK-Leipzig            490           490    490
# Thema                      491           491    491
# Specials                   508           508    508
# Stadtpolitik               546           546    546
# Kultur-Regional            751           751    751
# News                       783           783    783
# Boulevard                  810           810    810
# Taucha                    1392          1392   1392
# Mitteldeutschland         1476          1476   1476
# Kultur                    1566          1566   1566
# Sportbuzzer               1628          1628   1628
# Schkeuditz                2264          2264   2264
# Markkleeberg              2606          2606   2606
# Bad-Dueben                3196          3196   3196
# Eilenburg                 3582          3582   3582
# Polizeiticker-Leipzig     3720          3720   3720
# Geithain                  3724          3724   3724
# Wurzen                    3820          3820   3820
# Delitzsch                 4113          4113   4113
# Altenburg                 4395          4395   4395
# Polizeiticker             4481          4481   4481
# Grimma                    5595          5595   5595
# Oschatz                   5876          5876   5876
# Doebeln                   6268          6268   6268
# Borna                     7792          7792   7792
# Lokales                   7939          7939   7939
# Leipzig                  13399         13399  13399
